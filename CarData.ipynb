# %% [markdown]
# <a href="https://colab.research.google.com/github/AjayAajhey/gvassn/blob/main/CarData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4c827ebb-874b-4edc-b164-9e08a4349e61" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4c827ebb-874b-4edc-b164-9e08a4349e61">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car_data.csv to car_data.csv
# ...

# %%
df = pd.read_csv("car_data.csv")
df.head()
# Out:
#           Price  Mileage   Make    Model      Trim   Type  Cylinder  Liter  \
# 0  17314.103129     8221  Buick  Century  Sedan 4D  Sedan         6    3.1
# 1  17542.036083     9135  Buick  Century  Sedan 4D  Sedan         6    3.1
# 2  16218.847862    13196  Buick  Century  Sedan 4D  Sedan         6    3.1
# 3  16336.913140    16342  Buick  Century  Sedan 4D  Sedan         6    3.1
# 4  16339.170324    19832  Buick  Century  Sedan 4D  Sedan         6    3.1
#
#    Doors  Cruise  Sound  Leather
# 0      4       1      1        1
# 1      4       1      1        0
# 2      4       1      1        0
# 3      4       1      0        0
# 4      4       1      0        1

# %% [markdown]
# **Task 1**

# %%
import math
df["TMil"] =[math.sin(i) for i in df["Mileage"]]
df.head()
# Out:
#           Price  Mileage   Make    Model      Trim   Type  Cylinder  Liter  \
# 0  17314.103129     8221  Buick  Century  Sedan 4D  Sedan         6    3.1
# 1  17542.036083     9135  Buick  Century  Sedan 4D  Sedan         6    3.1
# 2  16218.847862    13196  Buick  Century  Sedan 4D  Sedan         6    3.1
# 3  16336.913140    16342  Buick  Century  Sedan 4D  Sedan         6    3.1
# 4  16339.170324    19832  Buick  Century  Sedan 4D  Sedan         6    3.1
#
#    Doors  Cruise  Sound  Leather      TMil
# 0      4       1      1        1  0.520959
# 1      4       1      1        0 -0.682689
# 2      4       1      1        0  0.966405
# 3      4       1      0        0 -0.535402
# 4      4       1      0        1  0.767173

# %%
df.corr()
# Out:
#              Price   Mileage  Cylinder     Liter     Doors    Cruise  \
# Price     1.000000 -0.143051  0.569086  0.558146 -0.138750  0.430851
# Mileage  -0.143051  1.000000 -0.029461 -0.018641 -0.016944  0.025037
# Cylinder  0.569086 -0.029461  1.000000  0.957897  0.002206  0.354285
# Liter     0.558146 -0.018641  0.957897  1.000000 -0.079259  0.377509
# Doors    -0.138750 -0.016944  0.002206 -0.079259  1.000000 -0.047674
# Cruise    0.430851  0.025037  0.354285  0.377509 -0.047674  1.000000
# Sound    -0.124348 -0.026146 -0.089704 -0.065527 -0.062530 -0.091730
# Leather   0.157197  0.001005  0.075520  0.087332 -0.061969 -0.070573
# TMil     -0.063581 -0.022115 -0.010061 -0.026483  0.027462  0.007001
#
#              Sound   Leather      TMil
# Price    -0.124348  0.157197 -0.063581
# Mileage  -0.026146  0.001005 -0.022115
# Cylinder -0.089704  0.075520 -0.010061
# Liter    -0.065527  0.087332 -0.026483
# Doors    -0.062530 -0.061969  0.027462
# ...

# %%
df.plot(x='TMil', y='Price', style='o')

plt.show()

# %%
X = df.iloc[:,1].values 
y = df.iloc[:, 0].values 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.45, random_state = 5)

# %%
from sklearn.linear_model import LinearRegression 
regressor = LinearRegression() 
regressor.fit(X_train.reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test.reshape(-1,1))

# %%
df1 = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1.head()
# Out:
#          Actual     Predicted
# 0   9506.047937  20599.345379
# 1  14429.789643  23467.989095
# 2   9919.048185  18374.471411
# 3  23249.841685  19613.589703
# 4  16927.779761  24029.210516

# %%
from sklearn import metrics
print(metrics.r2_score(y_test,y_pred))
# Out:
# 0.0118342527293549

# %% [markdown]
# **Task 2**

# %%
X1 = df[["Mileage","Cylinder","Liter","Doors","Cruise","Sound","Leather"]] 
y1 = df["Price"]
from sklearn.model_selection import train_test_split
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.45, random_state = 5)

# %%
from sklearn.linear_model import LinearRegression 
regressor = LinearRegression() 
regressor.fit(X1_train, y1_train)
# Out:
# LinearRegression()

# %%
y1_pred = regressor.predict(X1_test)

# %%
df2 = pd.DataFrame({'Actual': y1_test, 'Predicted': y1_pred})
df2.head()
# Out:
#            Actual     Predicted
# 207   9506.047937  14306.294733
# 330  14429.789643  21155.170163
# 199   9919.048185   5656.860194
# 648  23249.841685  15859.219489
# 620  16927.779761  14244.353009

# %%
from sklearn import metrics
print(metrics.r2_score(y1_test,y1_pred))
# Out:
# 0.4551489204217809

# %%
df.corr()
# Out:
#              Price   Mileage  Cylinder     Liter     Doors    Cruise  \
# Price     1.000000 -0.143051  0.569086  0.558146 -0.138750  0.430851
# Mileage  -0.143051  1.000000 -0.029461 -0.018641 -0.016944  0.025037
# Cylinder  0.569086 -0.029461  1.000000  0.957897  0.002206  0.354285
# Liter     0.558146 -0.018641  0.957897  1.000000 -0.079259  0.377509
# Doors    -0.138750 -0.016944  0.002206 -0.079259  1.000000 -0.047674
# Cruise    0.430851  0.025037  0.354285  0.377509 -0.047674  1.000000
# Sound    -0.124348 -0.026146 -0.089704 -0.065527 -0.062530 -0.091730
# Leather   0.157197  0.001005  0.075520  0.087332 -0.061969 -0.070573
# TMil     -0.063581 -0.022115 -0.010061 -0.026483  0.027462  0.007001
#
#              Sound   Leather      TMil
# Price    -0.124348  0.157197 -0.063581
# Mileage  -0.026146  0.001005 -0.022115
# Cylinder -0.089704  0.075520 -0.010061
# Liter    -0.065527  0.087332 -0.026483
# Doors    -0.062530 -0.061969  0.027462
# ...

# %% [markdown]
# From the correlation values we can conclude that cylinder, liter and cruise has good correlation with price

# %% [markdown]
# **Hard Task**

# %%
X2 = df[["Cylinder","Liter","Cruise","Leather"]] 
y2 = df["Price"]
from sklearn.model_selection import train_test_split
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.215, random_state = 5)

# %%
from sklearn.linear_model import LinearRegression 
regressor = LinearRegression() 
regressor.fit(X2_train, y2_train)
# Out:
# LinearRegression()

# %%
y2_pred = regressor.predict(X2_test)

# %%
from sklearn import metrics
print(metrics.r2_score(y2_test,y2_pred))
# Out:
# 0.4614241785240121
